# %% [markdown]
# # Understanding Nueral network

# %%
"""
Breakdown of simple neural network

X ---> input
Wx ---> Weights
bx ---> bias
A ---> Activation function
y ---> Output

## Forward Propagation
z = W1.x + b1
Z' = A(Z)
y = W2.z' + b2

After this  we need the loss dunction 

# Loss Function 

To find the Grident We need Back propagation
# Backporpagation
# Optimizer
"""
# Out:
# "\nBreakdown of simple neural network\n\nX ---> input\nWx ---> Weights\nbx ---> bias\nA ---> Activation function\ny ---> Output\n\n## Forward Propagation\nz = W1.x + b1\nZ' = A(Z)\ny = W2.z' + b2\n\nAfter this  we need the loss dunction \n\n# Loss Function \n\nTo find the Grident We need Back propagation\n# Backporpagation\n# Optimizer\n"

# %% [markdown]
# ## Components of pytorch
#
# - Base class for defining customer model : Torch.nn.module
# - Fully connected  (dense) layers : torch.nn.Linear
# - Activation function : torch.nn.ReLu
# - Optimizer : torch.Optim
# - Loss funcation : torch.nn.CrossEntropyLoss
# - loads data in batch : torch.utils.data.DataLoader

# %% [markdown]
# ## Different ways to create a nueral network
#
# 1. Function : Flexable , Hader to interpret
# 2. Sequential : nn.sequential

# %% [markdown]
# # Build a neural network

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
## Fuctional API 

class SimpleNN(nn.Module):
    
    def __init__(self, input_size, hidden_size, output_size):
        super(SimpleNN, self).__init__()
        
        self.fc1 = nn.Linear(input_size, hidden_size)
        
        self.relu = nn.ReLU()
        
        self.fc2 = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        return x

# %%
## Sequentail 

class simpleNNSequentail(nn.Module):
    
    def __inti__(self,input_size,hidden_size,output_size):
        super(simpleNNSequentail,self).__init__()
        
        self.network = nn.Sequential(
            nn.Linear(input_size,hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size,output_size)
        )
    
    def forward(self,x):
        return  self.network(x)

# %% [markdown]
# ## Training the neural network

# %%
model_fun= SimpleNN(input_size=4, hidden_size=8, output_size=3)
print(model_fun)
# Out:
# SimpleNN(
#   (fc1): Linear(in_features=4, out_features=8, bias=True)
#   (relu): ReLU()
#   (fc2): Linear(in_features=8, out_features=3, bias=True)
# )

# %%
X = torch.randn(10, 4) # 10 samples, 4 feature

Y = torch.randint(0,3,(10,))

criterion = nn.CrossEntropyLoss()
optimizer =  optim.Adam(model_fun.parameters(),lr=0.01)

# %%
print(X)
# Out:
# tensor([[-0.7563, -0.3727,  0.2594, -1.7089],
#         [-0.5398,  1.4638,  1.1158, -0.5782],
#         [ 0.4037,  0.4179,  0.6873, -0.8860],
#         [-0.5542,  1.6214, -1.8531,  1.3527],
#         [ 0.3534, -0.4154, -2.2264, -0.0798],
#         [ 0.0615,  0.4914,  0.6076, -0.4731],
#         [-0.8884,  1.0051,  1.1139, -0.1651],
#         [-0.1445, -0.2644,  0.3817, -1.1647],
#         [ 0.6105, -0.6419, -0.1884, -0.4830],
#         [ 1.6179,  1.5625,  0.4736, -2.1978]])

# %%
print(Y)
# Out:
# tensor([2, 2, 0, 0, 2, 0, 0, 1, 2, 0])

# %% [markdown]
# ## Simple Training Loop

# %%
# training loop

epoch = 120

for e in range(epoch):
    optimizer.zero_grad()
    output = model_fun(X)
    loss = criterion(output,Y)
    loss.backward()
    optimizer.step()
    
    if (e+1) % 10 == 0 : 
        print(f"Epoch[{e+1}]/50, Loss: {loss.item():.4f}")
# Out:
# Epoch[10]/50, Loss: 0.9774
# Epoch[20]/50, Loss: 0.8419
# Epoch[30]/50, Loss: 0.7274
# Epoch[40]/50, Loss: 0.6100
# Epoch[50]/50, Loss: 0.5124
# Epoch[60]/50, Loss: 0.4352
# Epoch[70]/50, Loss: 0.3711
# Epoch[80]/50, Loss: 0.3157
# Epoch[90]/50, Loss: 0.2658
# Epoch[100]/50, Loss: 0.2229
# Epoch[110]/50, Loss: 0.1856
# Epoch[120]/50, Loss: 0.1547
