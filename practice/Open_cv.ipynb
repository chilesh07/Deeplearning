# %% [markdown]
# # Open CV2

# %%
import os 
import xml.etree.ElementTree as ET
from sklearn.model_selection import train_test_split
import shutil
import numpy as np
import pandas as  pd
import cv2

# %%
image =cv2.imread("C:/Users/chilesh/Desktop/yolo/practice/helmet.jpg")

# %%
## Check the image is load or not

if image is None:
    print("Error in loading")
else:
    print("Image Loaded successfully ")
# Out:
# Image Loaded successfully

# %%
cv2.imshow("Image",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
image_new = image + 30
cv2.imwrite("out_image.jpg",image)
# Out:
# True

# %% [markdown]
# ## Load the Video

# %%
video =  cv2.VideoCapture('17853291-uhd_3840_2160_30fps.mp4')

# %%
while True:
    ret ,frame = video.read()
    if not ret:
        break
    cv2.imshow("Video Frame",frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

video.release()
cv2.destroyAllWindows()

# %%
## write the video
video =  cv2.VideoCapture('17853291-uhd_3840_2160_30fps.mp4')
fourcc = cv2.VideoWriter_fourcc(*"mp4v")

width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
Hight = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(video.get(cv2.CAP_PROP_FPS))
out = cv2.VideoWriter('output.mp4',fourcc , fps ,(width,Hight))

while True:
    ret,frame = video.read()
    if not ret:
        break
    out.write(frame)

out.release()
video.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## Colour correction

# %%
bgr_image = image

# %%
# Convert to grayscale

gray_image = cv2.cvtColor(bgr_image,cv2.COLOR_BGR2GRAY)
cv2.imwrite("gray_image.jpg",gray_image)
# Out:
# True

# %%
hsv_image = cv2.cvtColor(bgr_image,cv2.COLOR_BGR2HSV)
cv2.imwrite("hsv_image.jpg",hsv_image)
# Out:
# True

# %%
lab_image = cv2.cvtColor(bgr_image,cv2.COLOR_BGR2Lab)
cv2.imwrite("lab_image.jpg",lab_image)
# Out:
# True

# %%
## Convert to rgb 
rgb_image = cv2.cvtColor(bgr_image,cv2.COLOR_BGR2RGB)
cv2.imwrite("rgb_image.jpg",rgb_image)
# Out:
# True

# %%
## Convert to rgb
cv2.imwrite("Bgr_image.jpg",bgr_image)
# Out:
# True

# %% [markdown]
# ## Color Thresholding
#
# 1. it is a technique to filter our the specific range of colors in an image by defining upper and lower
