# %% [markdown]
# ## Road Damage Detection

# %%
# !pip install ultralytics
# Out:
# ...
#   Using cached ultralytics_thop-2.0.18-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# ...
#    ---------------------------------------- 0.0/6.2 MB ? eta -:--:--
#    -------------------- ------------------- 3.1/6.2 MB 37.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.7/6.2 MB 9.1 MB/s eta 0:00:01
#    ------------------------------------- -- 5.8/6.2 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------- 6.2/6.2 MB 7.9 MB/s  0:00:00
# Using cached ultralytics_thop-2.0.18-py3-none-any.whl (28 kB)
# Using cached fsspec-2026.2.0-py3-none-any.whl (202 kB)
# ...
#
#   Attempting uninstall: sympy
#
#     Found existing installation: sympy 1.14.0
#
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#    ---------------------------------------- 0/3 [sympy]
#     Uninstalling sympy-1.14.0:
# ...

# %%
# !yolo task=detect mode=train model=yolo11n.pt data=data.yaml epochs=25 imgsz=640
# Out:
# ...
# Ultralytics 8.4.14  Python-3.12.12 torch-2.5.1 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...
